# %% [markdown]
# # Livro para consulta:
# - https://jakevdp.github.io/PythonDataScienceHandbook/03.08-aggregation-and-grouping.html
# - https://jakevdp.github.io/PythonDataScienceHandbook/03.09-pivot-tables.html

# %% [markdown]
# # 1. Importando bibliotecas <a name="import"></a>
#
# <div style="text-align: right"
#
# [Voltar ao índice](#Contents)

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline

# %% [markdown]
# # 2. Carregando o dataframe SINASC <a name="read"></a>
# <div style="text-align: right"
#
# [Voltar ao índice](#Contents)

# %% [markdown]
# ### 1. Crie 2 faixas de Latitude do município (munResLat) sendo uma acima e outra abaixo de -10.5 e aplique o groupby usando essas faixas como chave e realize operações de soma, media, minimo, maximo, mediana, desvio padrao, variancia pra pelo menos 2 variáveis numéricas ainda não utilizadas

# %%
sin = pd.read_csv('SINASC_RO_2019.csv')
sin.columns
# Out:
# Index(['ORIGEM', 'CODESTAB', 'CODMUNNASC', 'LOCNASC', 'IDADEMAE', 'ESTCIVMAE',
#        'ESCMAE', 'CODOCUPMAE', 'QTDFILVIVO', 'QTDFILMORT', 'CODMUNRES',
#        'GESTACAO', 'GRAVIDEZ', 'PARTO', 'CONSULTAS', 'DTNASC', 'HORANASC',
#        'SEXO', 'APGAR1', 'APGAR5', 'RACACOR', 'PESO', 'IDANOMAL', 'DTCADASTRO',
#        'CODANOMAL', 'NUMEROLOTE', 'VERSAOSIST', 'DTRECEBIM', 'DIFDATA',
#        'DTRECORIGA', 'NATURALMAE', 'CODMUNNATU', 'CODUFNATU', 'ESCMAE2010',
#        'SERIESCMAE', 'DTNASCMAE', 'RACACORMAE', 'QTDGESTANT', 'QTDPARTNOR',
#        'QTDPARTCES', 'IDADEPAI', 'DTULTMENST', 'SEMAGESTAC', 'TPMETESTIM',
#        'CONSPRENAT', 'MESPRENAT', 'TPAPRESENT', 'STTRABPART', 'STCESPARTO',
#        'TPNASCASSI', 'TPFUNCRESP', 'TPDOCRESP', 'DTDECLARAC', 'ESCMAEAGR1',
#        'STDNEPIDEM', 'STDNNOVA', 'CODPAISRES', 'TPROBSON', 'PARIDADE',
#        'KOTELCHUCK', 'CONTADOR', 'munResStatus', 'munResTipo', 'munResNome',
# ...

# %%
sin.groupby('munResNome')['munResLat'].mean().sort_values()
# Out:
# munResNome
# Cabixi                      -13.49976
# Pimenteiras do Oeste        -13.47656
# Cerejeiras                  -13.19503
# Colorado do Oeste           -13.13056
# Corumbiara                  -12.99752
# Vilhena                     -12.74137
# Chupinguaia                 -12.55684
# Costa Marques               -12.43601
# Parecis                     -12.17983
# Alto Alegre dos Parecis     -12.13178
# São Francisco do Guaporé    -12.06380
# Alta Floresta D'Oeste       -11.93554
# São Felipe D'Oeste          -11.91439
# Santa Luzia D'Oeste         -11.90842
# Primavera de Rondônia       -11.82571
# Seringueiras                -11.76712
# Rolim de Moura              -11.72226
# Nova Brasilândia D'Oeste    -11.72133
# Novo Horizonte do Oeste     -11.70974
# São Miguel do Guaporé       -11.69949
# Pimenta Bueno               -11.67754
# Espigão D'Oeste             -11.52855
# Cacoal                      -11.43387
# Castanheiras                -11.42684
# ...

# %%
# Out:
#            ORIGEM   CODESTAB  CODMUNNASC  LOCNASC  IDADEMAE  ESTCIVMAE  \
# munResLat
# -11.93554       1  2679477.0      110001        1        19        5.0
# -11.93554       1  2679477.0      110001        1        29        2.0
# -11.93554       1  2679477.0      110001        1        37        9.0
# -12.13178       1  2516500.0      110001        1        30        5.0
# -11.93554       1  2516500.0      110001        1        30        2.0
# ...           ...        ...         ...      ...       ...        ...
# -12.74137       1  2604388.0      510340        1        32        2.0
# -12.55684       1  2752654.0      510675        1        19        1.0
# -12.74137       1  9659366.0      510787        1        24        2.0
# -12.74137       1  9659366.0      510787        1        21        2.0
# -11.70974       1  2795655.0      510792        1        18        5.0
#
#                     ESCMAE  CODOCUPMAE  QTDFILVIVO  QTDFILMORT  ...  PARIDADE  \
# ...

# %% [markdown]
# # Tarefa 2

# %% [markdown]
# ### 1. Crie 2 faixas de Latitude do município (munResLat) sendo uma acima e outra abaixo de -10.5 e aplique o groupby usando essas faixas como chave e realize operações de soma, media, minimo, maximo, mediana, desvio padrao, variancia pra pelo menos 2 variáveis numéricas ainda não utilizadas

# %%
sin_lat = sin.set_index('munResLat')
latitude = {
-13.49976 : 'lat1',
-13.47656 : 'lat1',
-13.19503 : 'lat1',
-13.13056 : 'lat1',
-12.99752 : 'lat1',
-12.74137 : 'lat1',
-12.55684 : 'lat1',
-12.43601 : 'lat1',
-12.17983 : 'lat1',
-12.13178 : 'lat1',
-12.06380 : 'lat1',
-11.93554 : 'lat1',
-11.91439 : 'lat1',
-11.90842 : 'lat1',
-11.82571 : 'lat1',
-11.76712 : 'lat1',
-11.72226 : 'lat1',
-11.72133 : 'lat1',
-11.70974 : 'lat1',
-11.69949 : 'lat1',
-11.67754 : 'lat1',
-11.52855 : 'lat1',
-11.43387 : 'lat1',
-11.42684 : 'lat1',
-11.34413 : 'lat1',
-11.19624 : 'lat1',
-11.17321 : 'lat1',
-11.12855 : 'lat1',
-11.04561 : 'lat1',
-10.93217 : 'lat1',
-10.91553 : 'lat1',
-10.88205 : 'lat1',
-10.77388 : 'lat1',
-10.72357 : 'lat1',
-10.61207 : 'lat1',
-10.56842 : 'lat1',
-10.43595 : 'lat2',
-10.43105 : 'lat2',
-10.41177 : 'lat2',
-10.33887 : 'lat2',
-10.26310 : 'lat2',
-10.24873 : 'lat2',
-10.20981 : 'lat2',
-9.90846 : 'lat2',
-9.85139 : 'lat2',
-9.71667 : 'lat2',
-9.70554 : 'lat2',
-9.42556 : 'lat2',
-9.37819 : 'lat2',
-9.19187 : 'lat2',
-8.78502 : 'lat2',
-8.76889 : 'lat2'
}
sin_lat.groupby(latitude)[['QTDPARTNOR','QTDPARTCES']].agg([np.mean,sum,min,np.std,np.var])
# Out:
#      QTDPARTNOR                                  QTDPARTCES               \
#            mean     sum  min       std       var       mean     sum  min
# lat1   0.452242  5800.0  0.0  1.123426  1.262087   0.552570  7095.0  0.0
# lat2   0.711759  8771.0  0.0  1.279042  1.635949   0.487335  6041.0  0.0
#
#
#            std       var
# lat1  0.753036  0.567062
# lat2  0.737899  0.544495

# %% [markdown]
# ### 2. Crie 2 faixas da área dos municípios (munResArea) sendo uma acima e outra abaixo de 3000 e aplique o groupby usando essas faixas como chave e realize operações de soma, media, minimo, maximo, mediana, desvio padrao, variancia pra pelo menos 2 variáveis numéricas ainda não utilizadas

# %%
sin.groupby('munResNome')['munResArea'].mean().sort_values()
# Out:
# munResNome
# Teixeirópolis                  459.978
# São Felipe D'Oeste             541.647
# Primavera de Rondônia          605.692
# Ministro Andreazza             798.083
# Nova União                     807.126
# Urupá                          831.857
# Novo Horizonte do Oeste        843.446
# Castanheiras                   892.842
# Vale do Paraíso                965.676
# Mirante da Serra              1191.875
# Santa Luzia D'Oeste           1197.796
# Cabixi                        1314.352
# Colorado do Oeste             1451.060
# Rolim de Moura                1457.888
# Nova Brasilândia D'Oeste      1703.008
# Rio Crespo                    1717.640
# Presidente Médici             1758.465
# Monte Negro                   1931.378
# Cacaulândia                   1961.778
# Ouro Preto do Oeste           1969.850
# Theobroma                     2197.413
# Parecis                       2548.683
# Alto Paraíso                  2651.822
# Cerejeiras                    2783.300
# ...

# %%
sin_area = sin.set_index('munResArea')
area = {
459.978 : 'area1',
541.647 : 'area1',
605.692 : 'area1',
798.083 : 'area1',
807.126 : 'area1',
831.857 : 'area1',
843.446 : 'area1',
892.842 : 'area1',
965.676 : 'area1',
1191.875 : 'area1',
1197.796 : 'area1',
1314.352 : 'area1',
1451.060 : 'area1',
1457.888 : 'area1',
1703.008 : 'area1',
1717.640 : 'area1',
1758.465 : 'area1',
1931.378 : 'area1',
1961.778 : 'area1',
1969.850 : 'area1',
2197.413 : 'area1',
2548.683 : 'area1',
2651.822 : 'area1',
2783.300 : 'area1',
2944.128 : 'area1',
3029.189 : 'area2',
3060.321 : 'area2',
3135.106 : 'area2',
3265.809 : 'area2',
3442.005 : 'area2',
3773.505 : 'area2',
3792.998 : 'area2',
3863.943 : 'area2',
3958.273 : 'area2',
4081.583 : 'area2',
4426.571 : 'area2',
4518.035 : 'area2',
4987.177 : 'area2',
5067.384 : 'area2',
5126.723 : 'area2',
6014.733 : 'area2',
6240.932 : 'area2',
6843.868 : 'area2',
6896.648 : 'area2',
7067.025 : 'area2',
7460.219 : 'area2',
8509.270 : 'area2',
10071.643 : 'area2',
10959.767 : 'area2',
11518.915 : 'area2',
24855.724 : 'area2',
34096.394 : 'area2',
}
sin_area.groupby(area)[['CONSPRENAT','CONSULTAS']].agg([np.mean,sum,min,max,np.median,np.std,np.var])
# Out:
#       CONSPRENAT                                                  CONSULTAS  \
#             mean       sum  min   max median       std        var      mean
# area1   8.709395   44775.0  0.0  99.0    8.0  4.290017  18.404248  3.740180
# area2   8.143825  170662.0  0.0  99.0    8.0  5.325530  28.361275  3.537326
#
#
#          sum min max median       std       var
# area1  19520   1   9      4  0.607492  0.369046
# area2  77142   1   9      4  0.820967  0.673986

# %%
sin.groupby('munResNome')['munResAlt'].mean().sort_values()
# Out:
# munResNome
# Candeias do Jamari            85.0
# Porto Velho                   87.0
# Itapuã do Oeste               99.0
# Cujubim                      111.0
# Rio Crespo                   124.0
# Alto Paraíso                 128.0
# Guajará-Mirim                133.0
# Ariquemes                    139.0
# Machadinho D'Oeste           144.0
# Costa Marques                145.0
# Nova Mamoré                  151.0
# Buritis                      153.0
# Vale do Paraíso              154.0
# Monte Negro                  155.0
# Ji-Paraná                    157.0
# Vale do Anari                158.0
# Cacaulândia                  161.0
# Jaru                         163.0
# São Francisco do Guaporé     166.0
# Pimenteiras do Oeste         170.0
# Cacoal                       177.0
# Presidente Médici            178.0
# Alvorada D'Oeste             182.0
# Pimenta Bueno                186.0
# Seringueiras                 186.0
# Teixeirópolis                191.0
# ...

# %% [markdown]
# ### 3. Determine faixas na variável munResAlt e aplique o groupby usando essas faixas como chave e realize operações de soma, media, minimo, maximo, mediana, desvio padrao, variancia pra pelo menos 2 variáveis numéricas ainda não utilizadas

# %%
sin_alt = sin.set_index('munResAlt')
alt = {
85.0 :'alt1',
87.0 :'alt1',
99.0 :'alt1',
111.0 :'alt1',
124.0 :'alt1',
128.0 :'alt1',
133.0 :'alt1',
139.0 :'alt1',
144.0 :'alt1',
145.0 :'alt1',
151.0 :'alt1',
153.0 :'alt1',
154.0 :'alt1',
155.0 :'alt1',
157.0 :'alt1',
158.0 :'alt1',
161.0 :'alt1',
163.0 :'alt1',
166.0 :'alt1',
170.0 :'alt1',
177.0 :'alt1',
178.0 :'alt1',
182.0 :'alt1',
186.0 :'alt1',
186.0 :'alt1',
191.0 :'alt1',
191.0 :'alt1',
192.0 :'alt1',
197.0 :'alt1',
202.0 :'alt2',
206.0 :'alt2',
212.0 :'alt2',
215.0 :'alt2',
227.0 :'alt2',
230.0 :'alt2',
236.0 :'alt2',
241.0 :'alt2',
245.0 :'alt2',
252.0 :'alt2',
259.0 :'alt2',
263.0 :'alt2',
263.0 :'alt2',
265.0 :'alt2',
266.0 :'alt2',
269.0 :'alt2',
270.0 :'alt2',
296.0 :'alt2',
338.0 :'alt2',
340.0 :'alt2',
397.0 :'alt2',
419.0 :'alt2',
595.0 :'alt2'
}
sin_alt.groupby(alt)[['TPFUNCRESP','QTDGESTANT']].agg([np.mean,sum,min,max,np.median,np.std,np.var])
# Out:
#      TPFUNCRESP                                               QTDGESTANT  \
#            mean      sum  min  max median       std       var       mean
# alt1   2.266978  47101.0  1.0  5.0    2.0  0.959170  0.920007   1.317655
# alt2   3.467411  21439.0  1.0  5.0    2.0  1.505043  2.265154   1.138884
#
#
#           sum  min   max median       std       var
# alt1  25913.0  0.0  52.0    1.0  1.454953  2.116888
# alt2   7003.0  0.0  12.0    1.0  1.220047  1.488515

# %% [markdown]
# ### 4. Plote no mesmo grafico ao longo do tempo a idade media das mulheres de cada regiao imediatas de rondonia
# https://pt.wikipedia.org/wiki/Lista_de_regi%C3%B5es_geogr%C3%A1ficas_intermedi%C3%A1rias_e_imediatas_de_Rond%C3%B4nia

# %%
sin_inter = sin.set_index('munResNome')
inter = {
"Candeias do Jamari" : "Porto Velho",
"Guajará-Mirim" : "Porto Velho",
"Itapuã do Oeste" : "Porto Velho",
"Nova Mamoré" : "Porto Velho",
"Porto Velho" : "Porto Velho",

"Alto Paraíso" : "Ariquemes",
"Ariquemes" : "Ariquemes",
"Buritis" : "Ariquemes",
"Cacaulândia" : "Ariquemes",
"Campo Novo de Rondônia" : "Ariquemes",
"Cujubim" : "Ariquemes",
"Monte Negro" : "Ariquemes",
"Rio Crespo" : "Ariquemes",

"Governador Jorge Teixeira" : "Jaru",
"Jaru" : "Jaru",
"Machadinho D'Oeste" : "Jaru",
"Theobroma" : "Jaru",
"Vale do Anari" : "Jaru",

"Alvorada D'Oeste" : "Ji-Paraná",
"Costa Marques" : "Ji-Paraná",
"Ji-Paraná" : "Ji-Paraná",
"Mirante da Serra" : "Ji-Paraná",
"Nova União" : "Ji-Paraná",
"Ouro Preto do Oeste" : "Ji-Paraná",
"Presidente Médici" : "Ji-Paraná",
"São Francisco do Guaporé" : "Ji-Paraná",
"São Miguel do Guaporé" : "Ji-Paraná",
"Seringueiras" : "Ji-Paraná",
"Teixeirópolis" : "Ji-Paraná",
"Urupá" : "Ji-Paraná",
"Vale do Paraíso" : "Ji-Paraná",

"Alta Floresta D'Oeste" : "Cacoal",
"Alto Alegre dos Parecis" : "Cacoal",
"Cacoal" : "Cacoal",
"Castanheiras" : "Cacoal",
"Espigão D'Oeste" : "Cacoal",
"Ministro Andreazza" : "Cacoal",
"Nova Brasilândia D'Oeste" : "Cacoal",
"Novo Horizonte do Oeste" : "Cacoal",
"Parecis" : "Cacoal",
"Pimenta Bueno" : "Cacoal",
"Primavera de Rondônia" : "Cacoal",
"Rolim de Moura" : "Cacoal",
"Santa Luzia D'Oeste" : "Cacoal",
"São Felipe D'Oeste" : "Cacoal",

"Cabixi" : "Vilhena",
"Cerejeiras" : "Vilhena",
"Chupinguaia" : "Vilhena",
"Colorado do Oeste" : "Vilhena",
"Corumbiara" : "Vilhena",
"Pimenteiras do Oeste" : "Vilhena",
"Vilhena" : "Vilhena"
}

sin_inter.groupby([inter,'DTNASC'])['IDADEMAE'].mean().plot(figsize = [20,10])
sin_inter.groupby([inter,'DTNASC'])['IDADEMAE'].mean()
# Out:
#            DTNASC
# Ariquemes  2019-01-01    23.200000
#            2019-01-02    26.166667
#            2019-01-03    24.142857
#            2019-01-04    24.666667
#            2019-01-05    22.888889
#                            ...
# Vilhena    2019-12-27    27.000000
#            2019-12-28    22.666667
#            2019-12-29    24.250000
#            2019-12-30    26.600000
#            2019-12-31    23.857143
# Name: IDADEMAE, Length: 2181, dtype: float64

# %% [markdown]
# ### 5. Utilize a tabela do link abaixo e crie faixas utilizando o mapping e gere agrupamentos utilizando essas faixas como chave

# %% [markdown]
# ### 5.1 IDH
# A - https://pt.wikipedia.org/wiki/Lista_de_munic%C3%ADpios_de_Rond%C3%B4nia_por_IDH-M

# %%
sin_idh = sin.set_index('munResNome')
idh = {
"Porto Velho" : "idh_alto", 	
"Vilhena" : "idh_alto", 	
"Cacoal" : "idh_alto", 	
"Ji-Paraná" : "idh_alto", 	
"Pimenta Bueno" : "idh_alto", 	
"Ariquemes" : "idh_alto", 	
"Rolim de Moura" : "idh_alto",

"Cerejeiras" : "idh_m", 
"Jaru" : "idh_m",
"Colorado do Oeste" : "idh_m", 
"Ouro Preto do Oeste" : "idh_m", 
"Espigão D'Oeste" : "idh_m",
"Santa Luzia D'Oeste" : "idh_m", 
"Pimenteiras do Oeste" : "idh_m", 
"Presidente Médici" : "idh_m", 
"Castanheiras" : "idh_m", 
"Guajará-Mirim" : "idh_m", 
"Chupinguaia" : "idh_m", 
"Cabixi" : "idh_m", 
"Candeias do Jamari" : "idh_m", 
"São Felipe D'Oeste" : "idh_m", 
"Cacaulândia" : "idh_m", 
"São Miguel do Guaporé" : "idh_m", 
"Mirante da Serra" : "idh_m", 
"Alvorada D'Oeste" : "idh_m", 
"Teixeirópolis" : "idh_m", 
"Nova Brasilândia D'Oeste" : "idh_m", 
"Rio Crespo" : "idh_m", 
"Primavera de Rondônia" : "idh_m", 
"Alta Floresta D'Oeste" : "idh_m", 
"Ministro Andreazza" : "idh_m", 
"Novo Horizonte do Oeste" : "idh_m", 
"Vale do Paraíso" : "idh_m", 
"Alto Paraíso" : "idh_m", 
"Parecis" : "idh_m", 
"Buritis" : "idh_m", 
"Itapuã do Oeste" : "idh_m", 
"Corumbiara" : "idh_m", 
"Cujubim" : "idh_m", 
"Costa Marques" : "idh_m", 
"São Francisco do Guaporé" : "idh_m", 
"Urupá" : "idh_m", 
"Monte Negro" : "idh_m", 

"Seringueiras" : "idh_b",
"Governador Jorge Teixeira" : "idh_b", 
"Machadinho D'Oeste" : "idh_b", 
"Campo Novo de Rondônia" : "idh_b", 
"Alto Alegre dos Parecis" : "idh_b", 
"Theobroma" : "idh_b", 
"Nova União" : "idh_b", 
"Nova Mamoré" : "idh_b", 
"Vale do Anari" : "idh_b"
}

sin_idh.groupby([idh])['IDADEMAE'].mean().plot(figsize = [20,10])

# dado interessante, é que a idade da mãe cai de acordo com o idh, como mostra o grafico abaixo
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### 5.2 IFDM
# B - https://pt.wikipedia.org/wiki/Lista_de_munic%C3%ADpios_de_Rond%C3%B4nia_por_IFDM

# %%
sin_ifdm = sin.set_index('munResNome')
ifdm = {
"Ariquemes" : "Moderado",
"Vilhena" : "Moderado",
"Pimenta Bueno" : "Moderado", 
"Porto Velho" : "Moderado", 
"Ji-Paraná" : "Moderado", 
"Cacoal" : "Moderado", 
"Santa Luzia D'Oeste" : "Moderado", 
"Rolim de Moura" : "Moderado", 
"Chupinguaia" : "Moderado", 
"São Miguel do Guaporé" : "Moderado", 
"Pimenteiras do Oeste" : "Moderado", 
"Teixeirópolis" : "Moderado", 
"Colorado do Oeste" : "Moderado", 
"Jaru" : "Moderado", 
"Rio Crespo" : "Moderado", 
"Primavera de Rondônia" : "Moderado", 
"Alta Floresta D'Oeste" : "Moderado", 
"Ouro Preto do Oeste" : "Moderado", 
"São Francisco do Guaporé" : "Moderado", 
"Candeias do Jamari" : "Moderado", 
"Buritis" : "Moderado", 
"São Felipe D'Oeste" : "Moderado", 
"Presidente Médici" : "Moderado", 
"Cerejeiras" : "Moderado", 
"Monte Negro" : "Moderado", 
"Urupá" : "Moderado",

"Espigão D'Oeste" : "Regular",
"Seringueiras" : "Regular", 
"Alvorada D'Oeste" : "Regular", 
"Itapuã do Oeste" : "Regular", 
"Cabixi" : "Regular", 
"Novo Horizonte do Oeste" : "Regular", 
"Nova Brasilândia D'Oeste" : "Regular", 
"Vale do Paraíso" : "Regular", 
"Corumbiara" : "Regular", 
"Alto Paraíso" : "Regular", 
"Cacaulândia" : "Regular", 
"Vale do Anari" : "Regular", 
"Ministro Andreazza" : "Regular", 
"Costa Marques" : "Regular", 
"Nova União" : "Regular", 
"Guajará-Mirim" : "Regular", 
"Mirante da Serra" : "Regular", 
"Parecis" : "Regular", 
"Castanheiras" : "Regular", 
"Theobroma" : "Regular", 
"Machadinho D'Oeste" : "Regular", 
"Campo Novo de Rondônia" : "Regular", 
"Nova Mamoré" : "Regular", 
"Cujubim" : "Regular", 
"Alto Alegre dos Parecis" : "Regular", 
"Governador Jorge Teixeira" : "Regular" 
}

sin_ifdm.groupby([ifdm])[['RACACORMAE']].mean().plot(figsize = [20,10])
#sendo Tipo de raça e cor da mãe: 1– Branca; 2– Preta; 3– Amarela; 4– Parda; 5– Indígena

#vemos a disparidade do indice de acordo com a 'RACACORMAE'
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### 5.3 PIB
# C - https://pt.wikipedia.org/wiki/Lista_de_munic%C3%ADpios_de_Rond%C3%B4nia_por_PIB

# %% [markdown]
# ### Analise as respostas encontradas, tire algum insight delas, conte pra gente algo encontrado nos dados.

# %% [markdown]
# Exemplo:
# - Ah, descobri que a idade mediana das mulheres que deram a luz no ano de 2019 dos municipios com o PIB mais alto é a maior dentre todas.

# %%
sin_pib = sin.set_index('munResNome')

pib = {

"Porto Velho" : "+1bi",
"Ji-Paraná" : "+1bi",
"Vilhena" : "+1bi",
"Ariquemes" : "+1bi",
"Cacoal" : "+1bi",
"Jaru" : "+1bi",
"Rolim de Moura" : "+1bi",
"Pimenta Bueno" : "+1bi",

"Guajará-Mirim" : "+500m",
"Ouro Preto do Oeste" : "+500m",
"Buritis" : "+500m",
"Machadinho do Oeste" : "+500m",
"Espigão D'Oeste" : "+500m",
"São Miguel do Guaporé" : "+500m",
"Candeias do Jamari" : "+500m",
"Nova Mamoré" : "+500m",
"Cerejeiras" : "+500m",

"Alta Floresta do Oeste" : "+300m",
"Presidente Médici" : "+300m",
"Cujubim" : "+300m",
"Nova Brasilândia do Oeste" : "+300m",
"Alto Paraíso" : "+300m",
"São Francisco do Guaporé" : "+300m",
"Colorado do Oeste" : "+300m",

"Monte Negro" : "+200m",
"Alto Alegre dos Parecis" : "+200m",
"Campo Novo de Rondônia" : "+200m",
"Alvorada do Oeste" : "+200m",

"Chupinguaia" : "+100m",
"Corumbiara" : "+100m",
"Ministro Andreazza" : "+100m",
"Urupá" : "+100m",
"Costa Marques" : "+100m",
"Seringueiras" : "+100m",
"Mirante da Serra" : "+100m",
"Governador Jorge Teixeira" : "+100m",
"Theobroma" : "+100m",
"Santa Luzia do Oeste" : "+100m",
"Novo Horizonte do Oeste" : "+100m",
"Itapuã do Oeste" : "+100m",
"Vale do Paraíso" : "+100m",
"Cacaulândia" : "+100m",
"Cabixi" : "+100m",
"Vale do Anari" : "+100m",

"Nova União" : "-100m",
"Parecis" : "-100m",
"Rio Crespo" : "-100m",
"Pimenteiras do Oeste" : "-100m",
"Teixeirópolis" : "-100m",
"São Felipe do Oeste" : "-100m",
"Castanheiras" : "-100m",
"Primavera de Rondônia" : "-100m"
}

sin_pib.groupby([pib])['QTDPARTNOR'].mean().plot(figsize = [20,10])
# Out:
# <AxesSubplot:>

# %%
#vimos no gráfico acima que as cidades com o menos pib, realizam menos partos normais, em média.
